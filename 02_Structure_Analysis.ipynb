# %%
from mp_api.client import MPRester
import py3Dmol


API_KEY = "TYPE_YOUR_API_KEY_HERE"

with MPRester(API_KEY) as mpr:
    data = mpr.materials.summary.search(
        material_ids=["mp-804"], 
        fields=["structure", "band_gap", "formula_pretty"]
    )[0]

structure = data.structure
gap = data.band_gap

print(f"材料: {data.formula_pretty}")
print(f"能隙 (Band Gap): {gap:.2f} eV")


# 判斷導電性
if gap == 0:
    print("這是金屬 (Metal)")
elif 0 < gap <= 3.0:
    print(f"這是典型的半導體")
elif 3.0 < gap <= 5.0:
    print(f"這是寬能隙半導體")
else:
    print(f"這是絕緣體")

# 3D 視覺化 
cif_str = structure.to(fmt="cif")
viewer = py3Dmol.view(width=400, height=400)
viewer.addModel(cif_str, "cif")
viewer.setStyle({'sphere': {'colorscheme': 'carbon', 'scale': 0.3}, 'stick': {'radius': 0.1}})
viewer.addUnitCell()
viewer.zoomTo()
viewer.show()
# Out:
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<00:00, 9404.27it/s]
# 材料: GaN
# 能隙 (Band Gap): 1.73 eV
# 這是典型的半導體
# <div id="3dmolviewer_17753116559800882"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17753116559800882" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
# ...
